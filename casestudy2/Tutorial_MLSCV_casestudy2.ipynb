# %%
# opencv is pre-installed in google colab
import cv2
# to check whether CV installed or not, just check its version
cv2.__version__
# Out:
# '4.1.2'

# %%
from google.colab import drive 
drive.mount('/content/drive')

# numpy package is suitable for matrix operations and has many functions to do complicated operations
# numpy gives us the basic MATlab features in python

import numpy as np
from google.colab.patches import cv2_imshow 

# reading images

img = cv2.imread('/content/drive/MyDrive/sem6/mlscv/casestudy2/originallenna.jpg', 0)


cv2_imshow(img)
print(img.shape)
print(img)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FBA9036E9D0>
# (512, 512)
# [[163 161 162 ... 170 156 127]
#  [163 161 162 ... 167 154 128]
#  [162 162 162 ... 171 156 129]
#  ...
#  [ 42  45  50 ... 103 104  97]
#  [ 43  46  54 ... 103 107 106]
#  [ 43  46  54 ... 104 105 108]]

# %%
# accessing the values of image matrix
print(img[:,0])

# what is the average intensity of the image
img_sum = 0
for i in range(img.shape[0]):
  for j in range(img.shape[1]):
    img_sum = img_sum + img[i, j]

img_avg = img_sum/(img.shape[0]*img.shape[1])
print(img_avg)
# Out:
# [163 163 162 162 162 163 161 157 155 156 155 155 158 158 156 159 157 158
#  159 152 157 154 157 156 156 153 155 158 159 157 157 158 155 159 159 160
#  161 157 158 165 163 166 161 158 161 162 164 162 165 161 164 162 159 163
#  162 156 162 157 161 161 160 162 162 164 166 164 168 171 168 173 171 176
#  174 171 174 170 172 168 164 168 162 156 164 163 155 154 151 150 147 143
#  136 138 128 124 122 115 107 100 100  90  84  91  90  90  85  87  83  89
#   93  89  91  95  87 100  87  92  92  84  97  96  86  86  91  90  91  95
#   95  94  95  92  95  93  94  99  97  99 102 101 102  98  98 102 100 103
#   98 101  97 100 100 105 107 102  94  99  95  94 101  97  93 102  98  97
#   93  95  99  95  97  97  95  96  95  98 102  99  96 100  99 101  98  99
#  100  99 100  93  97 104  95 103 105 109 107 103 108 109 110 110 109 108
#  107 109 103 106 107 117 104 105 110 110 106 110 106 110 105 105 108 107
#  112 104 109 104 104 108  99 103 104  98 101 105 106 101 110 101 107 105
# ...

# %%
img_new = img*0.1
print(img_new[:][0])

# what is the average intensity of the image
img_sum = 0
for i in range(img.shape[0]):
  for j in range(img.shape[1]):
    # fill the next line
    img_sum = img_sum + img_new[i, j]

img_avg = img_sum/(img.shape[0]*img.shape[1])
print(img_avg)
# Out:
# [16.3 16.1 16.2 16.1 16.3 15.5 16.5 16.  16.5 16.  16.2 16.  15.4 16.3
#  16.  15.4 15.7 15.4 16.1 16.2 15.2 15.7 15.4 15.7 15.3 15.8 15.4 15.1
#  15.6 15.5 15.2 15.6 15.5 15.6 15.6 16.1 15.7 16.8 15.9 16.6 16.6 16.5
#  16.6 17.4 16.9 17.6 17.3 16.9 17.1 17.3 16.6 17.5 16.7 16.9 16.2 16.1
#  14.8 14.9 15.5 13.9 13.  12.  11.7 10.6  9.6  9.8  9.3  9.1  8.9  9.7
#  10.2  9.6 10.3 10.  10.6 10.5 10.5 10.6 10.3 11.1 11.  10.7 10.8 10.5
#  10.4 10.8 10.9 10.9 10.8 10.6 10.8 10.9 11.1 10.9 10.6 10.9 10.9 11.2
#  10.8 10.8 10.4 10.6 10.5 10.9 11.  11.1 11.7 11.  11.1 11.9 12.3 11.7
#  11.3 12.1 12.1 12.3 12.6 12.2 12.  12.3 12.4 13.1 12.9 12.3 12.2 12.7
#  13.2 13.  13.2 12.8 13.7 12.7 12.9 13.  13.  12.8 13.3 13.5 13.4 13.3
#  13.1 13.2 12.8 12.9 13.2 12.8 12.9 12.4 13.4 13.  12.9 13.1 12.8 13.3
#  12.8 12.8 13.5 13.2 13.7 13.4 12.8 13.6 12.8 13.6 13.4 13.4 13.3 13.6
#  13.3 13.4 13.1 13.6 13.4 13.3 13.3 13.2 13.6 13.3 13.4 13.4 13.3 13.2
# ...

# %%
# Generate a random noise matrix 
noise_matrix =  np.random.randn(1000, 1000)
print(np.average(noise_matrix)) 
print(np.std(noise_matrix))
# Out:
# -0.001666568922138419
# 1.0007426592984885

# %%
# Resizing the image


cv2_imshow(img)
shrink_img = cv2.resize(img, (100, 100),
               interpolation = cv2.INTER_NEAREST)
cv2_imshow(shrink_img)

zoom_img = cv2.resize(shrink_img, (512, 512),
               interpolation = cv2.INTER_NEAREST)
cv2_imshow(zoom_img)


shrink_img = cv2.resize(img, (100, 100),
               interpolation = cv2.INTER_LINEAR)
cv2_imshow(shrink_img)

zoom_img = cv2.resize(shrink_img, (512, 512),
               interpolation = cv2.INTER_LINEAR)
cv2_imshow(zoom_img)

shrink_img = cv2.resize(img, (100, 100),
               interpolation = cv2.INTER_CUBIC)
cv2_imshow(shrink_img)

zoom_img = cv2.resize(shrink_img, (512, 512),
               interpolation = cv2.INTER_CUBIC)
cv2_imshow(zoom_img)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FBA90351B50>
# <PIL.Image.Image image mode=L size=100x100 at 0x7FBA90351A50>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FBA90351A50>
# <PIL.Image.Image image mode=L size=100x100 at 0x7FBA90351A50>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FBA90351A50>
# <PIL.Image.Image image mode=L size=100x100 at 0x7FBA90351A50>
# <PIL.Image.Image image mode=L size=512x512 at 0x7FBA90351A50>

# %%
# image rotation

image_rotated = cv2.rotate(img, cv2.cv2.ROTATE_90_CLOCKWISE)
cv2_imshow(image_rotated)
# Out:
# <PIL.Image.Image image mode=L size=512x512 at 0x7FBA9036D2D0>

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow 

# reading images
img = cv2.imread('/content/drive/MyDrive/sem6/mlscv/casestudy2/chess_noisy.bmp', 0)


cv2_imshow(img)
print(img.shape)
print(img)


blur = cv2.blur(img,(53,53))
cv2_imshow(blur)


filtersize = 53
blur_gauss = cv2.GaussianBlur(img, (filtersize, filtersize), 128)
cv2_imshow(blur_gauss)


kernel = np.ones((53,53),np.float32)/(53*53)
blur_1 = cv2.filter2D(src=img, ddepth=-1, kernel=kernel)


cleaned = img - blur_1
cv2_imshow(cleaned)


cleaned_1 = np.divide(img, blur)
cv2_imshow(cleaned_1)
# Out:
# <PIL.Image.Image image mode=L size=286x286 at 0x7FBA91BC44D0>
# (286, 286)
# [[ 32  32  32 ... 148 148 148]
#  [ 32  32  32 ... 149 149 148]
#  [ 32  32  32 ... 149 149 148]
#  ...
#  [148 149 149 ...  32  32  32]
#  [148 149 149 ...  32  32  32]
#  [148 148 148 ...  32  32  32]]
# <PIL.Image.Image image mode=L size=286x286 at 0x7FBA9035FF10>
# <PIL.Image.Image image mode=L size=286x286 at 0x7FBA91BC4350>
# <PIL.Image.Image image mode=L size=286x286 at 0x7FBAA0A52610>
# <PIL.Image.Image image mode=L size=286x286 at 0x7FBA91BC4C50>

# %%
# Example of using sklearn

import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Load the diabetes dataset
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)
print(diabetes_X.shape)
print(diabetes_y.shape)


# Use only one feature
diabetes_X = diabetes_X[:, 2]
diabetes_X = diabetes_X.reshape(diabetes_X.shape[0], 1)

# Split the data into training/testing sets
diabetes_X_train = diabetes_X[:-20]
diabetes_X_test = diabetes_X[-20:]

# Split the targets into training/testing sets
diabetes_y_train = diabetes_y[:-20]
diabetes_y_test = diabetes_y[-20:]

# Create linear regression object
model = linear_model.LinearRegression()

# Train the model using the training sets
model.fit(diabetes_X_train, diabetes_y_train)

# Make predictions using the testing set
diabetes_y_pred = model.predict(diabetes_X_test)

# The coefficients
print("Coefficients: \n", model.coef_)
# The mean squared error
print("Mean squared error: %.2f" % mean_squared_error(diabetes_y_test, diabetes_y_pred))


# Plot outputs
plt.scatter(diabetes_X_test, diabetes_y_test, color="black")
plt.plot(diabetes_X_test, diabetes_y_pred, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()
# Out:
# (442, 10)
# (442,)
# Coefficients:
#  [938.23786125]
# Mean squared error: 2548.07

# %%
print(model)
# Out:
# LinearRegression()

# %%
from sklearn.datasets import load_digits 
import numpy as np 
import matplotlib.pyplot as plt 

from sklearn import datasets, linear_model 
from sklearn.model_selection import train_test_split 


digits = load_digits()

# Print to show there are 1797 images (8 by 8 images for a dimensionality of 64)
print( digits.data.shape)
# Print to show there are 1797 labels (integers from 0–9)
print( digits.target.shape)

x_train, x_test, y_train, y_test = train_test_split(digits.data, digits.target, test_size=0.25, random_state=0)

# all parameters not specified are set to their defaults
model = linear_model.LogisticRegression(solver='lbfgs', max_iter=10000)
model.fit(x_train, y_train)

# Returns a NumPy Array
# Predict for One Observation (image)
plt.figure()
plt.imshow(np.reshape(x_test[0], (8,8)), cmap=plt.cm.gray)


M = model.predict(x_test[0].reshape(1,-1))
print("The output number for the test image is")
print(M)

# Use score method to get accuracy of model
score = model.score(x_test, y_test)
print("The overall accuracy of the test data")
print(score)
# Out:
# (1797, 64)
# (1797,)
# The output number for the test image is
# [2]
# The overall accuracy of the test data
# 0.9533333333333334

# %%
diabetes_X, diabetes_y = datasets.load_diabetes(return_X_y=True)
diabetes_X[:, 2]
# Out:
# array([ 0.06169621, -0.05147406,  0.04445121, -0.01159501, -0.03638469,
#        -0.04069594, -0.04716281, -0.00189471,  0.06169621,  0.03906215,
#        -0.08380842,  0.01750591, -0.02884001, -0.00189471, -0.02560657,
#        -0.01806189,  0.04229559,  0.01211685, -0.0105172 , -0.01806189,
#        -0.05686312, -0.02237314, -0.00405033,  0.06061839,  0.03582872,
#        -0.01267283, -0.07734155,  0.05954058, -0.02129532, -0.00620595,
#         0.04445121, -0.06548562,  0.12528712, -0.05039625, -0.06332999,
#        -0.03099563,  0.02289497,  0.01103904,  0.07139652,  0.01427248,
#        -0.00836158, -0.06764124, -0.0105172 , -0.02345095,  0.06816308,
#        -0.03530688, -0.01159501, -0.0730303 , -0.04177375,  0.01427248,
#        -0.00728377,  0.0164281 , -0.00943939, -0.01590626,  0.0250506 ,
#        -0.04931844,  0.04121778, -0.06332999, -0.06440781, -0.02560657,
#        -0.00405033,  0.00457217, -0.00728377, -0.0374625 , -0.02560657,
# ...
